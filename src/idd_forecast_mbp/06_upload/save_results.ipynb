# %%
import subprocess
import time
from rra_tools.shell_tools import mkdir # type: ignore
from idd_forecast_mbp import constants as rfc

cause_map = rfc.cause_map
measure_map = rfc.measure_map
ssp_scenarios = rfc.ssp_scenarios

run_date = "2025_06_30"


commands = []
for cause in cause_map:
    for ssp_scenario in ssp_scenarios:
        scenario = ssp_scenarios[ssp_scenario]["dhs_scenario"]
        for measure in measure_map:
            measure_id = measure_map[measure]["measure_id"]
            cause_id = cause_map[cause]["cause_id"]
            command = f"/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_{cause_id}_measure_id_{measure_id}_scenario_{scenario}_{run_date} --has-past-data False"
            commands.append(command)

# %%
commands
# Out:
# ['/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_1_scenario_66_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_66_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_1_scenario_0_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_0_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_1_scenario_54_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_54_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_66_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_66_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_0_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_0_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_54_2025_06_30 --has-past-data False',
#  '/mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_54_2025_06_30 --has-past-data False']

# %%
# Store results in a list of dictionaries
results = []

# Execute commands sequentially and save results
for i, command in enumerate(commands):
    print(f"Running command {i+1}/{len(commands)}: {command}")
    
    result_data = {
        'command': command,
        'index': i,
        'success': False,
        'stdout': '',
        'stderr': '',
        'return_code': None
    }
    
    try:
        result = subprocess.run(command, shell=True, check=True, capture_output=True, text=True)
        print(f"Command {i+1} completed successfully")
        
        result_data['success'] = True
        result_data['stdout'] = result.stdout
        result_data['stderr'] = result.stderr
        result_data['return_code'] = result.returncode
        
        if result.stdout:
            print(f"Output: {result.stdout}")
            
    except subprocess.CalledProcessError as e:
        print(f"Command {i+1} failed with error: {e}")
        print(f"Error output: {e.stderr}")
        
        result_data['success'] = False
        result_data['stdout'] = e.stdout if e.stdout else ''
        result_data['stderr'] = e.stderr if e.stderr else ''
        result_data['return_code'] = e.returncode
    
    results.append(result_data)
    time.sleep(1)

print("All commands completed!")

# Now you can work with the results
# Example: Get all successful outputs
successful_outputs = [r['stdout'] for r in results if r['success']]

# Example: Get all failed commands
failed_commands = [r['command'] for r in results if not r['success']]

# Example: Process specific outputs
for result in results:
    if result['success'] and 'specific_text' in result['stdout']:
        # Do something with this specific output
        processed_output = result['stdout'].strip().upper()
        # Further processing...
# Out:
# Running command 1/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_1_scenario_66_2025_06_30 --has-past-data False
# Command 1 completed successfully
# Output: [2025-07-01 08:00:15 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:00:15 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:00:15 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:00:15 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:00:15 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:00:22 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:00:25 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:00:45 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 5.5sec
# [2025-07-01 08:00:45 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:00:45 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/death/FHS_save_results_2025_07_01_at_08_00_15_scenario_66_malaria
#
# Running command 2/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_66_2025_06_30 --has-past-data False
# Command 2 completed successfully
# Output: [2025-07-01 08:00:53 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:00:53 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:00:53 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:00:53 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:00:53 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:01:00 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:01:01 PDT] [WARNING] [fhs_pipeline_save_results.lib.rules.warn_greater_than_one : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_66_2025_06_30/draws.h5 contains value greater than one.
# [2025-07-01 08:01:02 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:01:21 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 4.4sec
# [2025-07-01 08:01:21 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:01:21 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/incidence/FHS_save_results_2025_07_01_at_08_00_53_scenario_66_malaria
#
# Running command 3/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_1_scenario_0_2025_06_30 --has-past-data False
# Command 3 completed successfully
# Output: [2025-07-01 08:01:28 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:01:28 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:01:28 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:01:28 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:01:28 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:01:34 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:01:37 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:01:52 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 4.26sec
# [2025-07-01 08:01:52 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:01:52 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/death/FHS_save_results_2025_07_01_at_08_01_28_scenario_0_malaria
#
# Running command 4/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_0_2025_06_30 --has-past-data False
# Command 4 completed successfully
# Output: [2025-07-01 08:02:01 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:02:01 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:02:01 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:02:01 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:02:01 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:02:08 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:02:09 PDT] [WARNING] [fhs_pipeline_save_results.lib.rules.warn_greater_than_one : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_0_2025_06_30/draws.h5 contains value greater than one.
# [2025-07-01 08:02:10 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:02:27 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 3.82sec
# [2025-07-01 08:02:27 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:02:27 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/incidence/FHS_save_results_2025_07_01_at_08_02_01_scenario_0_malaria
#
# Running command 5/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_1_scenario_54_2025_06_30 --has-past-data False
# Command 5 completed successfully
# Output: [2025-07-01 08:02:32 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:02:32 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:02:32 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:02:32 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:02:32 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:02:38 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:02:40 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:02:58 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 4.36sec
# [2025-07-01 08:02:58 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:02:58 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/death/FHS_save_results_2025_07_01_at_08_02_32_scenario_54_malaria
#
# Running command 6/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_54_2025_06_30 --has-past-data False
# Command 6 completed successfully
# Output: [2025-07-01 08:03:05 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:03:05 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:03:05 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:03:05 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:03:05 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:03:12 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:03:12 PDT] [WARNING] [fhs_pipeline_save_results.lib.rules.warn_greater_than_one : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_345_measure_id_6_scenario_54_2025_06_30/draws.h5 contains value greater than one.
# [2025-07-01 08:03:13 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:03:31 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 3.23sec
# [2025-07-01 08:03:31 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:03:31 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/incidence/FHS_save_results_2025_07_01_at_08_03_05_scenario_54_malaria
#
# Running command 7/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_66_2025_06_30 --has-past-data False
# Command 7 completed successfully
# Output: [2025-07-01 08:03:37 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:03:37 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:03:37 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:03:37 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:03:37 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:03:43 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:03:45 PDT] [INFO] [fhs_pipeline_save_results.lib.rules.contains_fhs_age_set : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_66_2025_06_30/draws.h5 contains rows with age restrictions. Dropping rows with the following age_group_ids: {2}.
# [2025-07-01 08:03:45 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:03:59 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 4.48sec
# [2025-07-01 08:03:59 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:03:59 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/death/FHS_save_results_2025_07_01_at_08_03_37_scenario_66_ntd_dengue
#
# Running command 8/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_66_2025_06_30 --has-past-data False
# Command 8 completed successfully
# Output: [2025-07-01 08:04:06 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:04:06 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:04:06 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:04:06 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:04:06 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:04:13 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:04:16 PDT] [INFO] [fhs_pipeline_save_results.lib.rules.contains_fhs_age_set : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_66_2025_06_30/draws.h5 contains rows with age restrictions. Dropping rows with the following age_group_ids: {2}.
# [2025-07-01 08:04:17 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:04:32 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 3.57sec
# [2025-07-01 08:04:32 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:04:32 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/incidence/FHS_save_results_2025_07_01_at_08_04_06_scenario_66_ntd_dengue
#
# Running command 9/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_0_2025_06_30 --has-past-data False
# Command 9 completed successfully
# Output: [2025-07-01 08:04:39 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:04:39 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:04:39 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:04:39 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:04:39 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:04:45 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:04:47 PDT] [INFO] [fhs_pipeline_save_results.lib.rules.contains_fhs_age_set : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_0_2025_06_30/draws.h5 contains rows with age restrictions. Dropping rows with the following age_group_ids: {2}.
# [2025-07-01 08:04:48 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:05:04 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 3.86sec
# [2025-07-01 08:05:04 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:05:04 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/death/FHS_save_results_2025_07_01_at_08_04_39_scenario_0_ntd_dengue
#
# Running command 10/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_0_2025_06_30 --has-past-data False
# Command 10 completed successfully
# Output: [2025-07-01 08:05:11 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:05:11 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:05:11 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:05:11 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:05:11 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:05:17 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:05:19 PDT] [INFO] [fhs_pipeline_save_results.lib.rules.contains_fhs_age_set : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_0_2025_06_30/draws.h5 contains rows with age restrictions. Dropping rows with the following age_group_ids: {2}.
# [2025-07-01 08:05:20 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:05:34 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 3.64sec
# [2025-07-01 08:05:34 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:05:34 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/incidence/FHS_save_results_2025_07_01_at_08_05_11_scenario_0_ntd_dengue
#
# Running command 11/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_54_2025_06_30 --has-past-data False
# Command 11 completed successfully
# Output: [2025-07-01 08:05:40 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:05:40 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:05:40 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:05:40 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:05:40 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:05:48 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:05:51 PDT] [INFO] [fhs_pipeline_save_results.lib.rules.contains_fhs_age_set : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_1_scenario_54_2025_06_30/draws.h5 contains rows with age restrictions. Dropping rows with the following age_group_ids: {2}.
# [2025-07-01 08:05:51 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:06:05 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 3.86sec
# [2025-07-01 08:06:05 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:06:05 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/death/FHS_save_results_2025_07_01_at_08_05_40_scenario_54_ntd_dengue
#
# Running command 12/12: /mnt/team/fhs/pub/venv/fhs_save_results /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_54_2025_06_30 --has-past-data False
# Command 12 completed successfully
# Output: [2025-07-01 08:06:12 PDT] [INFO] [fhs_pipeline_save_results.cli.console.main : 2.0.22] - Beginning FHS Save Results
# [2025-07-01 08:06:12 PDT] [WARNING] [fhs_lib_file_interface.lib.fs_implementations.wala_file_system.__init__ : 3.1.21] - WALAFileSystem is not using any remap functions. It will operate on exact FileSystemEntity objects that it is given.
# [2025-07-01 08:06:12 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Identified 1 files to upload.
# [2025-07-01 08:06:12 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Beginning upload for draws.h5 (#1/1)
# [2025-07-01 08:06:12 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Reading draws.h5.
# [2025-07-01 08:06:20 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Data read. Validating draws.h5.
# [2025-07-01 08:06:22 PDT] [INFO] [fhs_pipeline_save_results.lib.rules.contains_fhs_age_set : 2.0.22] - File /mnt/team/idd/pub/forecast-mbp/05-upload_data/fhs_upload_folders/cause_id_357_measure_id_6_scenario_54_2025_06_30/draws.h5 contains rows with age restrictions. Dropping rows with the following age_group_ids: {2}.
# [2025-07-01 08:06:23 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.etl_one_file : 2.0.22] - Validation complete. Uploading draws.h5.
# [2025-07-01 08:06:37 PDT] [INFO] [tiny_structured_logger.lib.fhs_logging.stopwatch : 3.2.15] - STOPWATCH timing for save_xr: 3.19sec
# [2025-07-01 08:06:37 PDT] [INFO] [fhs_pipeline_save_results.lib.etl.main : 2.0.22] - Upload for draws.h5 complete.
# [2025-07-01 08:06:37 PDT] [INFO] [fhs_pipeline_save_results.lib.etl._validate_and_save_logs : 2.0.22] - Save results complete. Files saved to: /ihme/forecasting/data/9/future/incidence/FHS_save_results_2025_07_01_at_08_06_12_scenario_54_ntd_dengue
#
# All commands completed!
